# %% [markdown]
# # Run A Preset Experiment
#
# Use the experiment registry instead of wiring models and datasets manually.

# %%
from grail_metabolism.experiments.presets import get_experiment_preset
config = get_experiment_preset('paper_minimal_baseline')
config.to_dict()

# %%
from grail_metabolism.experiments.runner import ExperimentRunner
# runner = ExperimentRunner()
# result = runner.run_config(config)
# result.metrics
