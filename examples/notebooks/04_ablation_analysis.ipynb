# %% [markdown]
# # Ablation Analysis
#
# Compare experiment outputs collected under `artifacts/`.

# %%
from grail_metabolism.experiments.runner import ExperimentRunner
from grail_metabolism.experiments.presets import get_experiment_preset

# %%
runner = ExperimentRunner()
configs = [
    get_experiment_preset('paper_minimal_baseline'),
    get_experiment_preset('paper_generator_dot'),
]
# results = runner.run_many(configs)
# runner.compare(results)
